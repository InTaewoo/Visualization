# %% [markdown]
# <a href="https://colab.research.google.com/github/InTaewoo/Visualization/blob/master/Seaborn/flight.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = sns.load_dataset('flights')

# %%
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
df.shape
# Out:
# (144, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %%
df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
#barplot
plt.figure(figsize=(10,4))
sns.barplot(data=df,x='year',y='passengers')

# %%
#lineplot
plt.figure(figsize=(10,4))
sns.lineplot(data=df,x='year',y='passengers')

# %%
#pointplot
plt.figure(figsize=(10,4))
sns.pointplot(data=df,x='year',y='passengers')

# %%
#barplot에 hue를 통해 Month 값에따라 색으로 나눠그리기
plt.figure(figsize=(10,4))
sns.barplot(data=df,x='year',y='passengers',hue='month')

# %%
plt.figure(figsize=(10,4))
sns.lineplot(data=df,x='year',y='passengers',hue='month')
plt.legend(bbox_to_anchor=(1.02,1), loc=2, borderaxespad=0.) #범례를 밖에 표시

# %%
plt.figure(figsize=(10,4))
sns.lineplot(data=df,x='month',y='passengers',hue='year')
plt.legend(bbox_to_anchor=(1.02,1), loc=2, borderaxespad=0.)

# %%
plt.figure(figsize=(15,4))
sns.boxplot(data=df,x='year',y='passengers')

# %%
plt.figure(figsize=(15,4))
sns.boxenplot(data=df,x='year',y='passengers')

# %%
plt.figure(figsize=(15,4))
sns.violinplot(data=df,x='year',y='passengers')

# %%
#산점도
plt.figure(figsize=(15,4))
sns.swarmplot(data=df,x='year',y='passengers')

# %%
#regplot
plt.figure(figsize=(15,4))
sns.regplot(data=df,x='year',y='passengers')
plt.show()

# %%
from datetime import datetime
year = 2021
month = 'March'

s = f'{year} {month} 1'
d = datetime.strptime(s, '%Y %B %d')
d.strftime('%Y-%m-%d')
# Out:
# '2021-03-01'

# %%
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
def find_datetime(row) :
    year = row['year']
    month = row['month']
    s= f'{year} {month} 1'
    d = datetime.strptime(s, '%Y %B %d')
    return d.strftime('%Y-%m-%d')

# %%
row = {'year':1949,'month':'January'}
find_datetime(row)
# Out:
# '1949-01-01'
