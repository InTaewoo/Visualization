# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
data = [10,20,30,40,50]

# %%
plt.plot(data)
plt.show()

# %%
import numpy as np

# %%
x = np.arange(-4.5,5,0.5)
y = 2*x**2

# %%
y
# Out:
# array([40.5, 32. , 24.5, 18. , 12.5,  8. ,  4.5,  2. ,  0.5,  0. ,  0.5,
#         2. ,  4.5,  8. , 12.5, 18. , 24.5, 32. , 40.5])

# %%
x
# Out:
# array([-4.5, -4. , -3.5, -3. , -2.5, -2. , -1.5, -1. , -0.5,  0. ,  0.5,
#         1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5])

# %%
plt.plot(x,y)

# %%
y1 = 2*x**2
y2 = 5*x + 30
y3 = 4*x**2 + 10

# %%
plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y3)
plt.show()

# %%
plt.plot(x,y1,x,y2,x,y3)
plt.show()

# %%
plt.figure() #새로운 그래프 창을 생성함

# %%
plt.plot(x,y1)
plt.figure()
plt.plot(x,y2)

# %%
x = np.arange(-5,5,0.1)
y1 = x**2 -2
y2 = 20*np.cos(x)**2

plt.figure(1)
plt.plot(x,y1)

plt.figure(2)
plt.plot(x,y2)

plt.figure(1)
plt.plot(x,y2)

# %%
plt.figure(1)
pl

# %%
plt.subplot(3,2,6)
# Out:
# <AxesSubplot:>

# %%
#데이터생성
x = np.arange(0,10,0.1)
y1 = 0.3*(x-5)**2+1
y2 = -1.5*x + 3
y3 = 10*np.sin(x)**2
y4 = 10*np.exp(-x)+1

#2 x 2 행렬로 이뤄진 하위 그래프에서 p에 따라 위치를 지정

plt.subplot(2,2,1) #p=1
plt.plot(x,y1)

plt.subplot(2,2,2) #p=2
plt.plot(x,y2)

plt.subplot(2,2,3) #p=3
plt.plot(x,y3)

plt.subplot(2,2,4) #p=4
plt.plot(x,y4)

# %%
x = np.linspace(-4,4,100) #[-4,4]범위에서 100개의 값 생성
y1 = x**3
y2 = 10*x**2 - 2
plt.plot(x,y1,x,y2)
plt.show()

# %%
# 위에 그래프 만나는 부분이 잘 보이지않을때 확대하는법
plt.plot(x,y1,x,y2)
plt.xlim(-1,1)
plt.ylim(-3,3)
plt.show()

# %%
#그래프 꾸미기
fmt = '[color][line_style][marker]'

# %%
fmt
# Out:
# '[color][line_style][marker]'

# %%
x = np.arange(0,5,1)
y1 = x
y2 = x+1
y3 = x+2
y4 = x+3

# %%
#색지정
plt.plot(x,y1,x,y2,x,y3,x,y4)
plt.show()

# %%
plt.plot(x,y1,'m',x,y2,'r',x,y3,'y',x,y4,'k')
plt.show()

# %%
#선스타일
plt.plot(x,y1,'-',x,y2,'--',x,y3,':',x,y4,'-.')
plt.show()

# %%
#마커표시
plt.plot(x,y1,'o',x,y2,'^',x,y3,'s',x,y4,'d')
plt.show()

# %%
# 혼합
plt.plot(x,y1,'>--r',x,y2,'s-g',x,y3,'d:b',x,y4,'-.xc')
plt.show()
